# %%
pip install pyserial
# Out:
# Requirement already satisfied: pyserial in /usr/local/share/pynq-venv/lib/python3.10/site-packages (3.5)
# WARNING: You are using pip version 22.0.2; however, version 25.2 is available.
# You should consider upgrading via the '/usr/local/share/pynq-venv/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import serial.tools.list_ports

ports = serial.tools.list_ports.comports()

for port in ports:
    print(f"Device: {port.device} | Description: {port.description}")
# Out:
# Device: /dev/ttyACM1 | Description: USB Roboclaw 2x30A

# %%
from roboclaw_3 import Roboclaw

rc = Roboclaw("/dev/ttyACM1", 115200)  # 또는 ttyUSB0
rc.Open()

address = 0x80
enc1, status1, valid1 = rc.ReadEncM1(address)
enc2, status2, valid2 = rc.ReadEncM2(address)

print("Encoder 1:", enc1, "Encoder 2:", enc2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 from roboclaw_3 import Roboclaw
#       3 rc = Roboclaw("/dev/ttyACM0", 115200)  # 또는 ttyUSB0
#       4 rc.Open()
#
# ModuleNotFoundError: No module named 'roboclaw_3'

# %%
success = rc.Open()
print("Connection opened:", success)
# Out:
# Connection opened: 1

# %%
import sys
sys.path.append("/home/xilinx/pynq/roboclaw")  # 실제 roboclaw_3.py가 있는 경로
from roboclaw_3 import Roboclaw

# %%
rc = Roboclaw("/dev/ttyACM1", 38400)  # 또는 ttyUSB0
rc.Open()

rc.ForwardM1(address, 0)
# Out:
# True

# %%
encoder_1_count = rc.ReadEncM1(0x80);
print(encoder_1_count)
# Out:
# (1, -148803, 130)
