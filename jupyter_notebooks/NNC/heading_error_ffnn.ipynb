# %%
from pynq import Overlay
from pynq import MMIO
from pynq.lib.iic import AxiIIC
import cffi, time
import threading
import csv
import math

overlay = Overlay("/home/xilinx/pynq/overlays/heading_error_ffnn.bit")
print(overlay.ip_dict.keys())
# Out:
# dict_keys(['top_heading_error_ff_0', 'axi_iic_0', 'processing_system7_0'])

# %%
overlay.ip_dict['top_heading_error_ff_0']
# Out:
# {'type': 'xilinx.com:hls:top_heading_error_ffnn:1.0',
#  'mem_id': 's_axi_control',
#  'memtype': 'REGISTER',
#  'gpio': {},
#  'interrupts': {},
#  'parameters': {'C_S_AXI_CONTROL_ADDR_WIDTH': '6',
#   'C_S_AXI_CONTROL_DATA_WIDTH': '32',
#   'Component_Name': 'design_1_top_heading_error_ff_0_0',
#   'II': '329',
#   'clk_period': '10',
#   'combinational': '0',
#   'latency': '328',
#   'machine': '64',
#   'EDK_IPTYPE': 'PERIPHERAL',
#   'C_S_AXI_CONTROL_BASEADDR': '0x40000000',
#   'C_S_AXI_CONTROL_HIGHADDR': '0x4000FFFF',
#   'ADDR_WIDTH': '6',
#   'ARUSER_WIDTH': '0',
#   'AWUSER_WIDTH': '0',
#   'BUSER_WIDTH': '0',
#   'CLK_DOMAIN': 'design_1_processing_system7_0_0_FCLK_CLK0',
#   'DATA_WIDTH': '32',
#   'FREQ_HZ': '100000000',
#   'HAS_BRESP': '1',
#   'HAS_BURST': '0',
#   'HAS_CACHE': '0',
#   'HAS_LOCK': '0',
#   'HAS_PROT': '0',
#   'HAS_QOS': '0',
#   'HAS_REGION': '0',
#   'HAS_RRESP': '1',
#   'HAS_WSTRB': '1',
#   'ID_WIDTH': '0',
#   'INSERT_VIP': '0',
#   'MAX_BURST_LENGTH': '1',
#   'NUM_READ_OUTSTANDING': '1',
#   'NUM_READ_THREADS': '1',
#   'NUM_WRITE_OUTSTANDING': '1',
#   'NUM_WRITE_THREADS': '1',
#   'PHASE': '0.0',
#   'PROTOCOL': 'AXI4LITE',
#   'READ_WRITE_MODE': 'READ_WRITE',
#   'RUSER_BITS_PER_BYTE': '0',
#   'RUSER_WIDTH': '0',
#   'SUPPORTS_NARROW_BURST': '0',
#   'WUSER_BITS_PER_BYTE': '0',
#   'WUSER_WIDTH': '0'},
#  'registers': {'CTRL': {'address_offset': 0,
#    'size': 32,
#    'access': 'read-write',
#    'description': 'Control signals',
#    'fields': {'AP_START': {'bit_offset': 0,
#      'bit_width': 1,
#      'access': 'read-write',
#      'description': "Control signal Register for 'ap_start'."},
#     'AP_DONE': {'bit_offset': 1,
#      'bit_width': 1,
#      'access': 'read-only',
#      'description': "Control signal Register for 'ap_done'."},
#     'AP_IDLE': {'bit_offset': 2,
#      'bit_width': 1,
#      'access': 'read-only',
#      'description': "Control signal Register for 'ap_idle'."},
#     'AP_READY': {'bit_offset': 3,
#      'bit_width': 1,
#      'access': 'read-only',
#      'description': "Control signal Register for 'ap_ready'."},
#     'RESERVED_1': {'bit_offset': 4,
#      'bit_width': 3,
#      'access': 'read-only',
#      'description': 'Reserved.  0s on read.'},
#     'AUTO_RESTART': {'bit_offset': 7,
#      'bit_width': 1,
#      'access': 'read-write',
#      'description': "Control signal Register for 'auto_restart'."},
#     'RESERVED_2': {'bit_offset': 8,
#      'bit_width': 1,
#      'access': 'read-only',
#      'description': 'Reserved.  0s on read.'},
#     'INTERRUPT': {'bit_offset': 9,
#      'bit_width': 1,
#      'access': 'read-only',
#      'description': "Control signal Register for 'interrupt'."},
#     'RESERVED_3': {'bit_offset': 10,
#      'bit_width': 22,
#      'access': 'read-only',
#      'description': 'Reserved.  0s on read.'}}},
#   'GIER': {'address_offset': 4,
#    'size': 32,
#    'access': 'read-write',
#    'description': 'Global Interrupt Enable Register',
#    'fields': {'Enable': {'bit_offset': 0,
#      'bit_width': 1,
#      'access': 'read-write',
#      'description': 'Master enable for the device interrupt output to the system interrupt controller: 0 = Disabled, 1 = Enabled'},
#     'RESERVED': {'bit_offset': 1,
#      'bit_width': 31,
#      'access': 'read-only',
#      'description': 'Reserved.  0s on read.'}}},
#   'IP_IER': {'address_offset': 8,
#    'size': 32,
#    'access': 'read-write',
#    'description': 'IP Interrupt Enable Register',
#    'fields': {'CHAN0_INT_EN': {'bit_offset': 0,
#      'bit_width': 1,
#      'access': 'read-write',
#      'description': 'Enable Channel 0 (ap_done) Interrupt.  0 = Disabled, 1 = Enabled.'},
#     'CHAN1_INT_EN': {'bit_offset': 1,
#      'bit_width': 1,
#      'access': 'read-write',
#      'description': 'Enable Channel 1 (ap_ready) Interrupt.  0 = Disabled, 1 = Enabled.'},
#     'RESERVED_0': {'bit_offset': 2,
#      'bit_width': 30,
#      'access': 'read-only',
#      'description': 'Reserved.  0s on read.'}}},
#   'IP_ISR': {'address_offset': 12,
#    'size': 32,
#    'access': 'read-write',
#    'description': 'IP Interrupt Status Register',
#    'fields': {'CHAN0_INT_ST': {'bit_offset': 0,
#      'bit_width': 1,
#      'access': 'read-only',
#      'description': 'Channel 0 (ap_done) Interrupt Status. 0 = No Channel 0 interrupt, 1 = Channel 0 interrupt.'},
#     'CHAN1_INT_ST': {'bit_offset': 1,
#      'bit_width': 1,
#      'access': 'read-only',
#      'description': 'Channel 1 (ap_ready) Interrupt Status. 0 = No Channel 1 interrupt, 1 = Channel 1 interrupt.'},
#     'RESERVED_0': {'bit_offset': 2,
#      'bit_width': 30,
#      'access': 'read-only',
#      'description': 'Reserved.  0s on read.'}}},
#   'Memory_new_data': {'address_offset': 16,
#    'size': 16,
#    'access': 'read-write',
#    'description': 'Memory new_data',
#    'fields': {}},
#   'Memory_output_r': {'address_offset': 32,
#    'size': 8,
#    'access': 'read-write',
#    'description': 'Memory output_r',
#    'fields': {}}},
#  'driver': pynq.overlay.DefaultIP,
#  'device': <pynq.pl_server.embedded_device.EmbeddedDevice at 0xb4867208>,
#  'state': None,
#  'bdtype': None,
#  'phys_addr': 1073741824,
#  'addr_range': 65536,
#  'fullpath': 'top_heading_error_ff_0'}

# %%
ADDR_BASE = 0x41600000
ADDR_RANGE = 0x10000
i2c_obj = MMIO(ADDR_BASE,ADDR_RANGE)
FFNN_ADDR_BASE = 0x40000000
FFNN_ADDR_RANGE = 0x10000
ffnn_obj = MMIO(FFNN_ADDR_BASE,FFNN_ADDR_RANGE)

# %%
i2c_obj.write(292,0)

# %%
iic_ip = overlay.ip_dict['axi_iic_0']
iic = AxiIIC(iic_ip)

ffi = cffi.FFI()

# %%
def read_(addr,reg,length=1):
    iic.send(addr,bytes([reg]),1,0)
    buf = ffi.new("unsigned char[]",length)
    iic.receive(addr, buf, length, 0)
    return [buf[i] for i in range(length)]

def write_(addr, reg, value):
    iic.send(addr, bytes([reg,value]), 2, 0)

def to_int16(low,high):
    val = (high << 8) | low
    if val & 0x8000:
        val -= 1 << 16
    return val

#하드웨어에 입력으로 넣기 위해 fixed16_8로 변환하는 함수
def float_to_fixed16_8(x):
    # 8 fractional bits → 256 곱함
    val = int(round(x * 256))  # 소수 반올림
    # 16비트 범위로 클리핑
    if val > 32767:
        val = 32767
    elif val < -32768:
        val = -32768
    return val

# %%
# BN0055 connection check
BN0055_addr = 0x28
chip_addr = 0x00
chip_id = read_(BN0055_addr, 0x00, 1)[0]
print("CHIP ID:", hex(chip_id)) #0xA0
# Out:
# CHIP ID: 0xa0

# %%
#NDOF mode on 0x0C

write_(BN0055_addr, 0x3D, 0X0C)
time.sleep(0.1)

# %%
#calibration check
cal = read_(BN0055_addr, 0x35, 1)[0]
sys = (cal >> 6) & 0x03
gyro = (cal >> 4) & 0x03
accel = (cal >> 2) & 0x03
mag = cal & 0x03

print(f"Cal : sys = {sys} Gyro = {gyro} accel = {accel} mag = {mag}")
# Out:
# Cal : sys = 0 Gyro = 3 accel = 3 mag = 0

# %%
# roboclaw encoder 
import serial.tools.list_ports

ports = serial.tools.list_ports.comports()

for port in ports:
    print(f"Device: {port.device} | Description: {port.description}")

import sys
sys.path.append("/home/xilinx/pynq/roboclaw")  # 실제 roboclaw_3.py가 있는 경로
from roboclaw_3 import Roboclaw

rc = Roboclaw("/dev/ttyACM0", 38400)  # 또는 ttyUSB0
rc.Open()

rc_address = 0x80

start_time_motor = time.time()
# Out:
# Device: /dev/ttyACM0 | Description: USB Roboclaw 2x30A

# %%
# ======================
# CSV 준비
# ======================
csv_file = "rover_data.csv"
with open(csv_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow([
        "time","label", "delta_encL", "delta_encR",
        "heading", "cmdL", "cmdR"
    ])

# %%
def main_loop():
    # 전역 변수 선언: 모터 제어 및 센서 로깅에 필요한 모든 변수를 선언합니다.
    global pattern_idx, start_time_motor, cmdL, cmdR
    global prev_encL, prev_encR
    
    prev_encL, prev_encR = rc.ReadEncM1(rc_address)[1], rc.ReadEncM2(rc_address)[1]
    
    data = read_(BN0055_addr, 0x08, 44)
    #initial_heading = to_int16(data[18], data[19]) / 16.0
    initial_heading = 340
    print(initial_heading)
    
    cmdL, cmdR = 15,15
    
    rc.ForwardM1(rc_address, cmdL)
    rc.ForwardM2(rc_address, cmdR)
    
    LOOP_PERIOD = 0.05
    
    
    # 목표 주기 설정 (20Hz = 0.05초)
    LOOP_PERIOD = 0.05 
    CORRECTION_PERIOD = 0.15
    
    last_correction_time = time.time()
    
    while True:
        loop_start_time = time.time()
        

        
        curr_time = loop_start_time
        
        # 엔코더 읽기 및 delta 계산
        encL = rc.ReadEncM1(rc_address)[1]
        encR = rc.ReadEncM2(rc_address)[1]
        
        # delta 계산 (이전 값 사용)
        delta_encL = encL - prev_encL
        delta_encR = encR - prev_encR
        
        # 다음 루프를 위한 이전 값 갱신
        prev_encL, prev_encR = encL, encR

        # IMU 읽기
        data = read_(BN0055_addr,0x08,44)
        cur_heading = to_int16(data[18],data[19]) / 16.0
        
        heading_error = (initial_heading - cur_heading + 540) % 360 - 180
        
        
        input_data = [1,0,0,delta_encL/100,delta_encR/100, heading_error]   
        fixed_input = [float_to_fixed16_8(v) for v in input_data]
        print(fixed_input)
        

        # write input
        # -----------
        INPUT_ADDR = 16

        num_input_words = (len(fixed_input) + 1) // 2
        for i in range(num_input_words):
            low = fixed_input[i*2] & 0xFFFF
            if i*2 + 1 < len(fixed_input):
                high = fixed_input[i*2 + 1] & 0xFFFF
            else:
                high = 0
            word = (high << 16) | low
            ffnn_obj.write(INPUT_ADDR + i*4, word)

        # -----------------------------
        # 4. ap_start = 1
        # CTRL register offset = 0x00
        # bit0 = ap_start
        # -----------------------------
        CTRL_ADDR = 0
        AP_START = 1

        ffnn_obj.write(CTRL_ADDR, AP_START)

        # -----------------------------
        # 5. ap_done 기다리기
        # CTRL bit1 = ap_done
        # -----------------------------
        AP_DONE_MASK = 1 << 1

        while True:
            ctrl_reg = ffnn_obj.read(CTRL_ADDR)
            if ctrl_reg & AP_DONE_MASK:
                break

        # -----------------------------
        # 6. 출력 읽기
        # -----------------------------
        OUTPUT_ADDR = 32

        output_fixed = []
        num_words = 1

        for i in range(num_words):   # num_words = 필요한 word 수 (출력값 / 2)
            word = ffnn_obj.read(OUTPUT_ADDR + i)
            low  = word & 0xFFFF            # lower 16bit
            high = (word >> 16) & 0xFFFF    # upper 16bit

            # signed 처리 (16비트 signed fixed)
            if low & 0x8000:
                low = -((~low & 0xFFFF) + 1)
            if high & 0x8000:
                high = -((~high & 0xFFFF) + 1)

            output_fixed.append(low)
            output_fixed.append(high)

        def fixed_to_float16_2(x):
            return float(x) / 16384.0               # 14 fractional bits

        output_float = [fixed_to_float16_2(v) for v in output_fixed]

        print("Raw Fixed Output:", output_fixed)
        print("Converted Float Output:", output_float)
        # ---------------------------
        # cmd값 변환
        # ---------------------------
        pred_cmdL = output_float[0] * 127
        pred_cmdR = output_float[1] * 127

        print(f"predicted cmdL={pred_cmdL:.2f}, cmdR={pred_cmdR:.2f}")
        

        cmdL = round(pred_cmdL)
        cmdR = round(pred_cmdR)
            

        
        rc.ForwardM1(rc_address, cmdL)
        rc.ForwardM2(rc_address, cmdR)
        
        label = "forward"

        # CSV 기록
        with open(csv_file, mode='a', newline='') as f:
            writer = csv.writer(f)
            writer.writerow([
                curr_time, label, delta_encL, delta_encR, cur_heading, cmdL, cmdR
            ])
            
        # =======================# 3. 루프 시간 맞추기 (Loop Timing)# =======================
        loop_end_time = time.time()
        time_elapsed = loop_end_time - loop_start_time
        
        # 남은 시간만큼 대기하여 전체 루프 시간을 LOOP_PERIOD에 맞춥니다.
        sleep_time = LOOP_PERIOD - time_elapsed
        if sleep_time > 0:
            time.sleep(sleep_time)

# %%
main_loop()
# Out:
# 340
# [256, 0, 0, 0, 0, -608]
# Raw Fixed Output: [1534, 909]
# Converted Float Output: [0.0936279296875, 0.05548095703125]
# predicted cmdL=11.89, cmdR=7.05
# [256, 0, 0, -20, -31, -608]
# Raw Fixed Output: [1368, 1292]
# Converted Float Output: [0.08349609375, 0.078857421875]
# predicted cmdL=10.60, cmdR=10.01
# [256, 0, 0, -18, -13, -576]
# Raw Fixed Output: [1449, 1085]
# Converted Float Output: [0.08843994140625, 0.06622314453125]
# predicted cmdL=11.23, cmdR=8.41
# [256, 0, 0, -26, -28, -576]
# Raw Fixed Output: [1449, 1292]
# Converted Float Output: [0.08843994140625, 0.078857421875]
# predicted cmdL=11.23, cmdR=10.01
# [256, 0, 0, -31, -28, -576]
# Raw Fixed Output: [1368, 1292]
# Converted Float Output: [0.08349609375, 0.078857421875]
# predicted cmdL=10.60, cmdR=10.01
# [256, 0, 0, -31, -28, -560]
# Raw Fixed Output: [1368, 1292]
# Converted Float Output: [0.08349609375, 0.078857421875]
# predicted cmdL=10.60, cmdR=10.01
# [256, 0, 0, -33, -33, -560]
# Raw Fixed Output: [1368, 1368]
# Converted Float Output: [0.08349609375, 0.08349609375]
# predicted cmdL=10.60, cmdR=10.60
# [256, 0, 0, -36, -33, -544]
# Raw Fixed Output: [1368, 1368]
# Converted Float Output: [0.08349609375, 0.08349609375]
# predicted cmdL=10.60, cmdR=10.60
# [256, 0, 0, -38, -36, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -36, -36, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -44, -38, -560]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -46, -44, -560]
# Raw Fixed Output: [1449, 1449]
# Converted Float Output: [0.08843994140625, 0.08843994140625]
# predicted cmdL=11.23, cmdR=11.23
# [256, 0, 0, -44, -41, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -46, -38, -528]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -44, -38, -528]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -38, -41, -528]
# Raw Fixed Output: [1368, 1534]
# Converted Float Output: [0.08349609375, 0.0936279296875]
# predicted cmdL=10.60, cmdR=11.89
# [256, 0, 0, -41, -38, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -41, -38, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -38, -38, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -38, -36, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -38, -36, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -38, -41, -544]
# Raw Fixed Output: [1368, 1534]
# Converted Float Output: [0.08349609375, 0.0936279296875]
# predicted cmdL=10.60, cmdR=11.89
# [256, 0, 0, -44, -41, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -41, -44, -560]
# Raw Fixed Output: [1449, 1449]
# Converted Float Output: [0.08843994140625, 0.08843994140625]
# predicted cmdL=11.23, cmdR=11.23
# [256, 0, 0, -44, -38, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -44, -44, -544]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -44, -41, -544]
# Raw Fixed Output: [1368, 1449]
# Converted Float Output: [0.08349609375, 0.08843994140625]
# predicted cmdL=10.60, cmdR=11.23
# [256, 0, 0, -41, -44, -544]
# Raw Fixed Output: [1449, 1449]
# Converted Float Output: [0.08843994140625, 0.08843994140625]
# predicted cmdL=11.23, cmdR=11.23
# [256, 0, 0, -46, -41, -544]
# Raw Fixed Output: [1449, 1449]
# Converted Float Output: [0.08843994140625, 0.08843994140625]
# predicted cmdL=11.23, cmdR=11.23
# [256, 0, 0, -44, -36, -512]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -44, -44, -512]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -41, -44, -512]
# Raw Fixed Output: [1368, 1534]
# Converted Float Output: [0.08349609375, 0.0936279296875]
# predicted cmdL=10.60, cmdR=11.89
# [256, 0, 0, -44, -41, -512]
# Raw Fixed Output: [1368, 1534]
# Converted Float Output: [0.08349609375, 0.0936279296875]
# predicted cmdL=10.60, cmdR=11.89
# [256, 0, 0, -44, -44, -512]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -46, -44, -512]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -44, -44, -512]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -46, -41, -512]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -44, -41, -496]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -44, -46, -512]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -46, -44, -512]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -46, -44, -512]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -46, -44, -496]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -46, -44, -496]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -49, -46, -496]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -46, -44, -480]
# Raw Fixed Output: [1449, 1623]
# Converted Float Output: [0.08843994140625, 0.09906005859375]
# predicted cmdL=11.23, cmdR=12.58
# [256, 0, 0, -46, -41, -464]
# Raw Fixed Output: [1449, 1534]
# Converted Float Output: [0.08843994140625, 0.0936279296875]
# predicted cmdL=11.23, cmdR=11.89
# [256, 0, 0, -46, -44, -464]
# Raw Fixed Output: [1449, 1623]
# Converted Float Output: [0.08843994140625, 0.09906005859375]
# predicted cmdL=11.23, cmdR=12.58
# [256, 0, 0, -46, -46, -448]
# Raw Fixed Output: [1534, 1717]
# Converted Float Output: [0.0936279296875, 0.10479736328125]
# predicted cmdL=11.89, cmdR=13.31
# [256, 0, 0, -46, -44, -448]
# Raw Fixed Output: [1449, 1623]
# Converted Float Output: [0.08843994140625, 0.09906005859375]
# predicted cmdL=11.23, cmdR=12.58
# [256, 0, 0, -1034, -993, -368]
# Raw Fixed Output: [1219, 1368]
# Converted Float Output: [0.07440185546875, 0.08349609375]
# predicted cmdL=9.45, cmdR=10.60
# [256, 0, 0, -26, -23, -384]
# Raw Fixed Output: [1623, 1449]
# Converted Float Output: [0.09906005859375, 0.08843994140625]
# predicted cmdL=12.58, cmdR=11.23
# [256, 0, 0, -46, -44, -368]
# Raw Fixed Output: [1534, 1815]
# Converted Float Output: [0.0936279296875, 0.11077880859375]
# predicted cmdL=11.89, cmdR=14.07
# [256, 0, 0, -61, -44, -352]
# Raw Fixed Output: [1623, 1815]
# Converted Float Output: [0.09906005859375, 0.11077880859375]
# predicted cmdL=12.58, cmdR=14.07
# [256, 0, 0, -49, -51, -352]
# Raw Fixed Output: [1534, 1919]
# Converted Float Output: [0.0936279296875, 0.11712646484375]
# predicted cmdL=11.89, cmdR=14.88
# [256, 0, 0, -54, -61, -352]
# Raw Fixed Output: [1623, 2142]
# Converted Float Output: [0.09906005859375, 0.1307373046875]
# predicted cmdL=12.58, cmdR=16.60
# [256, 0, 0, -59, -51, -352]
# Raw Fixed Output: [1717, 1815]
# Converted Float Output: [0.10479736328125, 0.11077880859375]
# predicted cmdL=13.31, cmdR=14.07
# [256, 0, 0, -61, -61, -368]
# Raw Fixed Output: [1815, 2028]
# Converted Float Output: [0.11077880859375, 0.123779296875]
# predicted cmdL=14.07, cmdR=15.72
# [256, 0, 0, -61, -61, -368]
# Raw Fixed Output: [1815, 2028]
# Converted Float Output: [0.11077880859375, 0.123779296875]
# predicted cmdL=14.07, cmdR=15.72
# [256, 0, 0, -67, -61, -352]
# Raw Fixed Output: [1919, 2028]
# Converted Float Output: [0.11712646484375, 0.123779296875]
# predicted cmdL=14.88, cmdR=15.72
# [256, 0, 0, -67, -59, -336]
# Raw Fixed Output: [1919, 2028]
# Converted Float Output: [0.11712646484375, 0.123779296875]
# predicted cmdL=14.88, cmdR=15.72
# [256, 0, 0, -69, -64, -336]
# Raw Fixed Output: [1919, 2142]
# Converted Float Output: [0.11712646484375, 0.1307373046875]
# predicted cmdL=14.88, cmdR=16.60
# [256, 0, 0, -72, -67, -336]
# Raw Fixed Output: [2028, 2261]
# Converted Float Output: [0.123779296875, 0.13800048828125]
# predicted cmdL=15.72, cmdR=17.53
# [256, 0, 0, -72, -72, -320]
# Raw Fixed Output: [2028, 2386]
# Converted Float Output: [0.123779296875, 0.1456298828125]
# predicted cmdL=15.72, cmdR=18.49
# [256, 0, 0, -72, -69, -336]
# Raw Fixed Output: [2142, 2261]
# Converted Float Output: [0.1307373046875, 0.13800048828125]
# predicted cmdL=16.60, cmdR=17.53
# [256, 0, 0, -72, -74, -352]
# Raw Fixed Output: [2142, 2386]
# Converted Float Output: [0.1307373046875, 0.1456298828125]
# predicted cmdL=16.60, cmdR=18.49
# [256, 0, 0, -77, -72, -352]
# Raw Fixed Output: [2261, 2386]
# Converted Float Output: [0.13800048828125, 0.1456298828125]
# predicted cmdL=17.53, cmdR=18.49
# [256, 0, 0, -77, -72, -352]
# Raw Fixed Output: [2261, 2386]
# Converted Float Output: [0.13800048828125, 0.1456298828125]
# predicted cmdL=17.53, cmdR=18.49
# [256, 0, 0, -82, -77, -336]
# Raw Fixed Output: [2386, 2516]
# Converted Float Output: [0.1456298828125, 0.153564453125]
# predicted cmdL=18.49, cmdR=19.50
# [256, 0, 0, -82, -82, -336]
# Raw Fixed Output: [2386, 2653]
# Converted Float Output: [0.1456298828125, 0.16192626953125]
# predicted cmdL=18.49, cmdR=20.56
# [256, 0, 0, -84, -84, -352]
# Raw Fixed Output: [2516, 2653]
# Converted Float Output: [0.153564453125, 0.16192626953125]
# predicted cmdL=19.50, cmdR=20.56
# [256, 0, 0, -90, -90, -352]
# Raw Fixed Output: [2653, 2795]
# Converted Float Output: [0.16192626953125, 0.17059326171875]
# predicted cmdL=20.56, cmdR=21.67
# [256, 0, 0, -97, -90, -352]
# Raw Fixed Output: [2943, 2795]
# Converted Float Output: [0.17962646484375, 0.17059326171875]
# predicted cmdL=22.81, cmdR=21.67
# [256, 0, 0, -105, -95, -336]
# Raw Fixed Output: [3097, 2943]
# Converted Float Output: [0.18902587890625, 0.17962646484375]
# predicted cmdL=24.01, cmdR=22.81
# [256, 0, 0, -115, -97, -304]
# Raw Fixed Output: [3258, 2943]
# Converted Float Output: [0.1988525390625, 0.17962646484375]
# predicted cmdL=25.25, cmdR=22.81
# [256, 0, 0, -113, -105, -288]
# Raw Fixed Output: [3258, 3097]
# Converted Float Output: [0.1988525390625, 0.18902587890625]
# predicted cmdL=25.25, cmdR=24.01
# [256, 0, 0, -115, -110, -272]
# Raw Fixed Output: [3424, 3258]
# Converted Float Output: [0.208984375, 0.1988525390625]
# predicted cmdL=26.54, cmdR=25.25
# [256, 0, 0, -123, -118, -272]
# Raw Fixed Output: [3597, 3424]
# Converted Float Output: [0.21954345703125, 0.208984375]
# predicted cmdL=27.88, cmdR=26.54
# [256, 0, 0, -131, -120, -240]
# Raw Fixed Output: [3776, 3424]
# Converted Float Output: [0.23046875, 0.208984375]
# predicted cmdL=29.27, cmdR=26.54
# [256, 0, 0, -141, -138, -224]
# Raw Fixed Output: [3961, 3961]
# Converted Float Output: [0.24176025390625, 0.24176025390625]
# predicted cmdL=30.70, cmdR=30.70
# [256, 0, 0, -151, -138, -192]
# Raw Fixed Output: [4152, 3961]
# Converted Float Output: [0.25341796875, 0.24176025390625]
# predicted cmdL=32.18, cmdR=30.70
# [256, 0, 0, -159, -146, -160]
# Raw Fixed Output: [4152, 4152]
# Converted Float Output: [0.25341796875, 0.25341796875]
# predicted cmdL=32.18, cmdR=32.18
# [256, 0, 0, -159, -151, -128]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -166, -161, -112]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -172, -172, -112]
# Raw Fixed Output: [4152, 4975]
# Converted Float Output: [0.25341796875, 0.30364990234375]
# predicted cmdL=32.18, cmdR=38.56
# [256, 0, 0, -174, -182, -112]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -184, -144]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -184, -160]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -192]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -187, -192]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -187, -208]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -256]
# Raw Fixed Output: [4152, 4975]
# Converted Float Output: [0.25341796875, 0.30364990234375]
# predicted cmdL=32.18, cmdR=38.56
# [256, 0, 0, -182, -184, -256]
# Raw Fixed Output: [4152, 4975]
# Converted Float Output: [0.25341796875, 0.30364990234375]
# predicted cmdL=32.18, cmdR=38.56
# [256, 0, 0, -184, -189, -272]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -189, -304]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -179, -304]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -187, -320]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -182, -187, -336]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -184, -336]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -195, -195, -320]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -179, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -179, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -182, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -184, -368]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -400]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -187, -184, -400]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -179, -416]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -182, -177, -464]
# Raw Fixed Output: [3776, 4349]
# Converted Float Output: [0.23046875, 0.26544189453125]
# predicted cmdL=29.27, cmdR=33.71
# [256, 0, 0, -174, -172, -448]
# Raw Fixed Output: [3776, 4349]
# Converted Float Output: [0.23046875, 0.26544189453125]
# predicted cmdL=29.27, cmdR=33.71
# [256, 0, 0, -169, -177, -432]
# Raw Fixed Output: [3776, 4552]
# Converted Float Output: [0.23046875, 0.27783203125]
# predicted cmdL=29.27, cmdR=35.28
# [256, 0, 0, -169, -174, -464]
# Raw Fixed Output: [3776, 4349]
# Converted Float Output: [0.23046875, 0.26544189453125]
# predicted cmdL=29.27, cmdR=33.71
# [256, 0, 0, -164, -164, -464]
# Raw Fixed Output: [3776, 3961]
# Converted Float Output: [0.23046875, 0.24176025390625]
# predicted cmdL=29.27, cmdR=30.70
# [256, 0, 0, -164, -161, -480]
# Raw Fixed Output: [3597, 3961]
# Converted Float Output: [0.21954345703125, 0.24176025390625]
# predicted cmdL=27.88, cmdR=30.70
# [256, 0, 0, -164, -159, -480]
# Raw Fixed Output: [3776, 3961]
# Converted Float Output: [0.23046875, 0.24176025390625]
# predicted cmdL=29.27, cmdR=30.70
# [256, 0, 0, -161, -159, -464]
# Raw Fixed Output: [3776, 3961]
# Converted Float Output: [0.23046875, 0.24176025390625]
# predicted cmdL=29.27, cmdR=30.70
# [256, 0, 0, -164, -156, -448]
# Raw Fixed Output: [3776, 3961]
# Converted Float Output: [0.23046875, 0.24176025390625]
# predicted cmdL=29.27, cmdR=30.70
# [256, 0, 0, -164, -154, -416]
# Raw Fixed Output: [3961, 3961]
# Converted Float Output: [0.24176025390625, 0.24176025390625]
# predicted cmdL=30.70, cmdR=30.70
# [256, 0, 0, -164, -156, -416]
# Raw Fixed Output: [3961, 4152]
# Converted Float Output: [0.24176025390625, 0.25341796875]
# predicted cmdL=30.70, cmdR=32.18
# [256, 0, 0, -166, -151, -384]
# Raw Fixed Output: [4152, 3961]
# Converted Float Output: [0.25341796875, 0.24176025390625]
# predicted cmdL=32.18, cmdR=30.70
# [256, 0, 0, -169, -156, -368]
# Raw Fixed Output: [4152, 4152]
# Converted Float Output: [0.25341796875, 0.25341796875]
# predicted cmdL=32.18, cmdR=32.18
# [256, 0, 0, -174, -159, -336]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -174, -166, -320]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -184, -182, -320]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -177, -169, -320]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -179, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -179, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -182, -368]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -172, -182, -416]
# Raw Fixed Output: [3776, 4761]
# Converted Float Output: [0.23046875, 0.29058837890625]
# predicted cmdL=29.27, cmdR=36.90
# [256, 0, 0, -174, -182, -400]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -174, -184, -416]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -182, -448]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -174, -174, -448]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -174, -174, -448]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -177, -169, -448]
# Raw Fixed Output: [3961, 4152]
# Converted Float Output: [0.24176025390625, 0.25341796875]
# predicted cmdL=30.70, cmdR=32.18
# [256, 0, 0, -174, -166, -448]
# Raw Fixed Output: [3776, 4152]
# Converted Float Output: [0.23046875, 0.25341796875]
# predicted cmdL=29.27, cmdR=32.18
# [256, 0, 0, -174, -166, -416]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -172, -166, -400]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -174, -164, -400]
# Raw Fixed Output: [3961, 4152]
# Converted Float Output: [0.24176025390625, 0.25341796875]
# predicted cmdL=30.70, cmdR=32.18
# [256, 0, 0, -174, -164, -384]
# Raw Fixed Output: [4152, 4152]
# Converted Float Output: [0.25341796875, 0.25341796875]
# predicted cmdL=32.18, cmdR=32.18
# [256, 0, 0, -174, -164, -368]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -166, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -169, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -166, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -169, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -179, -172, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -174, -174, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -174, -177, -384]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -192, -384]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -3779, -3776, -528]
# Raw Fixed Output: [15, 15]
# Converted Float Output: [0.00091552734375, 0.00091552734375]
# predicted cmdL=0.12, cmdR=0.12
# [256, 0, 0, -154, -169, -544]
# Raw Fixed Output: [3258, 3776]
# Converted Float Output: [0.1988525390625, 0.23046875]
# predicted cmdL=25.25, cmdR=29.27
# [256, 0, 0, -67, -69, -592]
# Raw Fixed Output: [1717, 1717]
# Converted Float Output: [0.10479736328125, 0.10479736328125]
# predicted cmdL=13.31, cmdR=13.31
# [256, 0, 0, -128, -123, -576]
# Raw Fixed Output: [3097, 2943]
# Converted Float Output: [0.18902587890625, 0.17962646484375]
# predicted cmdL=24.01, cmdR=22.81
# [256, 0, 0, -102, -92, -592]
# Raw Fixed Output: [2516, 2261]
# Converted Float Output: [0.153564453125, 0.13800048828125]
# predicted cmdL=19.50, cmdR=17.53
# [256, 0, 0, -125, -113, -544]
# Raw Fixed Output: [3097, 2795]
# Converted Float Output: [0.18902587890625, 0.17059326171875]
# predicted cmdL=24.01, cmdR=21.67
# [256, 0, 0, -102, -92, -512]
# Raw Fixed Output: [2653, 2386]
# Converted Float Output: [0.16192626953125, 0.1456298828125]
# predicted cmdL=20.56, cmdR=18.49
# [256, 0, 0, -108, -92, -464]
# Raw Fixed Output: [2943, 2653]
# Converted Float Output: [0.17962646484375, 0.16192626953125]
# predicted cmdL=22.81, cmdR=20.56
# [256, 0, 0, -105, -90, -448]
# Raw Fixed Output: [2943, 2516]
# Converted Float Output: [0.17962646484375, 0.153564453125]
# predicted cmdL=22.81, cmdR=19.50
# [256, 0, 0, -110, -100, -400]
# Raw Fixed Output: [3258, 2795]
# Converted Float Output: [0.1988525390625, 0.17059326171875]
# predicted cmdL=25.25, cmdR=21.67
# [256, 0, 0, -108, -97, -384]
# Raw Fixed Output: [3258, 2943]
# Converted Float Output: [0.1988525390625, 0.17962646484375]
# predicted cmdL=25.25, cmdR=22.81
# [256, 0, 0, -115, -102, -352]
# Raw Fixed Output: [3424, 3097]
# Converted Float Output: [0.208984375, 0.18902587890625]
# predicted cmdL=26.54, cmdR=24.01
# [256, 0, 0, -123, -108, -336]
# Raw Fixed Output: [3597, 3258]
# Converted Float Output: [0.21954345703125, 0.1988525390625]
# predicted cmdL=27.88, cmdR=25.25
# [256, 0, 0, -133, -118, -288]
# Raw Fixed Output: [3776, 3424]
# Converted Float Output: [0.23046875, 0.208984375]
# predicted cmdL=29.27, cmdR=26.54
# [256, 0, 0, -136, -123, -256]
# Raw Fixed Output: [3776, 3597]
# Converted Float Output: [0.23046875, 0.21954345703125]
# predicted cmdL=29.27, cmdR=27.88
# [256, 0, 0, -143, -136, -240]
# Raw Fixed Output: [3961, 3961]
# Converted Float Output: [0.24176025390625, 0.24176025390625]
# predicted cmdL=30.70, cmdR=30.70
# [256, 0, 0, -148, -141, -240]
# Raw Fixed Output: [3961, 4152]
# Converted Float Output: [0.24176025390625, 0.25341796875]
# predicted cmdL=30.70, cmdR=32.18
# [256, 0, 0, -156, -151, -240]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -161, -156, -240]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -161, -166, -256]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -169, -172, -288]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -169, -174, -304]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -174, -179, -336]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -184, -182, -320]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -184, -336]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -179, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -177, -179, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -182, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -184, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -195, -352]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -184, -182, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -179, -368]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -177, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -179, -368]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -400]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -179, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -179, -432]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -179, -174, -416]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -177, -174, -416]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -174, -169, -432]
# Raw Fixed Output: [3961, 4152]
# Converted Float Output: [0.24176025390625, 0.25341796875]
# predicted cmdL=30.70, cmdR=32.18
# [256, 0, 0, -174, -164, -416]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -172, -166, -400]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -174, -172, -416]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -172, -164, -400]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -174, -166, -384]
# Raw Fixed Output: [3961, 4152]
# Converted Float Output: [0.24176025390625, 0.25341796875]
# predicted cmdL=30.70, cmdR=32.18
# [256, 0, 0, -189, -177, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -3520, -3356, -144]
# Raw Fixed Output: [30, 27]
# Converted Float Output: [0.0018310546875, 0.00164794921875]
# predicted cmdL=0.23, cmdR=0.21
# [256, 0, 0, -151, -151, -112]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -59, -64, -144]
# Raw Fixed Output: [1717, 2516]
# Converted Float Output: [0.10479736328125, 0.153564453125]
# predicted cmdL=13.31, cmdR=19.50
# [256, 0, 0, -146, -148, -128]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -102, -120, -112]
# Raw Fixed Output: [2795, 4152]
# Converted Float Output: [0.17059326171875, 0.25341796875]
# predicted cmdL=21.67, cmdR=32.18
# [256, 0, 0, -148, -138, -160]
# Raw Fixed Output: [3961, 3961]
# Converted Float Output: [0.24176025390625, 0.24176025390625]
# predicted cmdL=30.70, cmdR=30.70
# [256, 0, 0, -128, -131, -160]
# Raw Fixed Output: [3597, 3961]
# Converted Float Output: [0.21954345703125, 0.24176025390625]
# predicted cmdL=27.88, cmdR=30.70
# [256, 0, 0, -159, -138, -128]
# Raw Fixed Output: [4349, 3961]
# Converted Float Output: [0.26544189453125, 0.24176025390625]
# predicted cmdL=33.71, cmdR=30.70
# [256, 0, 0, -154, -146, -144]
# Raw Fixed Output: [4152, 4152]
# Converted Float Output: [0.25341796875, 0.25341796875]
# predicted cmdL=32.18, cmdR=32.18
# [256, 0, 0, -161, -148, -128]
# Raw Fixed Output: [4349, 4349]
# Converted Float Output: [0.26544189453125, 0.26544189453125]
# predicted cmdL=33.71, cmdR=33.71
# [256, 0, 0, -172, -164, -128]
# Raw Fixed Output: [4349, 4552]
# Converted Float Output: [0.26544189453125, 0.27783203125]
# predicted cmdL=33.71, cmdR=35.28
# [256, 0, 0, -177, -169, -96]
# Raw Fixed Output: [4349, 4761]
# Converted Float Output: [0.26544189453125, 0.29058837890625]
# predicted cmdL=33.71, cmdR=36.90
# [256, 0, 0, -179, -177, -96]
# Raw Fixed Output: [4152, 4975]
# Converted Float Output: [0.25341796875, 0.30364990234375]
# predicted cmdL=32.18, cmdR=38.56
# [256, 0, 0, -182, -187, -128]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -192, -144]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -192, -195, -144]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -128]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -187, -144]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -187, -160]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -160]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -187, -184, -128]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -187, -182, -144]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -179, -144]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -179, -144]
# Raw Fixed Output: [4152, 4975]
# Converted Float Output: [0.25341796875, 0.30364990234375]
# predicted cmdL=32.18, cmdR=38.56
# [256, 0, 0, -184, -184, -144]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -187, -160]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -182, -192]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -179, -208]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -184, -224]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -182, -224]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -256]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -272]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -184, -288]
# Raw Fixed Output: [4152, 4975]
# Converted Float Output: [0.25341796875, 0.30364990234375]
# predicted cmdL=32.18, cmdR=38.56
# [256, 0, 0, -182, -179, -272]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -272]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -272]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -288]
# Raw Fixed Output: [4152, 4975]
# Converted Float Output: [0.25341796875, 0.30364990234375]
# predicted cmdL=32.18, cmdR=38.56
# [256, 0, 0, -182, -182, -288]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -288]
# Raw Fixed Output: [4152, 4975]
# Converted Float Output: [0.25341796875, 0.30364990234375]
# predicted cmdL=32.18, cmdR=38.56
# [256, 0, 0, -187, -187, -288]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -197, -197, -304]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -187, -182, -320]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -179, -320]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -184, -179, -320]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -177, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -177, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -172, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -177, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -174, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -172, -384]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -169, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -179, -172, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -174, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -169, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -169, -336]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -169, -320]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -174, -288]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -174, -304]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -177, -304]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -177, -272]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -179, -288]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -182, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -177, -177, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -192, -182, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -182, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -200, -384]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -182, -400]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -177, -179, -384]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -174, -177, -368]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -166, -164, -384]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -187, -187, -400]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -174, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -174, -177, -400]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -179, -172, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -169, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -182, -174, -320]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -172, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -172, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -169, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -174, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -177, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -177, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -172, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -172, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -174, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -174, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -189, -184, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -177, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -166, -177, -320]
# Raw Fixed Output: [3961, 4975]
# Converted Float Output: [0.24176025390625, 0.30364990234375]
# predicted cmdL=30.70, cmdR=38.56
# [256, 0, 0, -179, -177, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -189, -179, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -179, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -177, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -177, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -177, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -179, -416]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -177, -177, -416]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -174, -172, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -179, -400]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -400]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -179, -174, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -177, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -177, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -177, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -336]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# ...
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -174, -179, -368]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -174, -177, -384]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -177, -179, -400]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -177, -179, -384]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -177, -182, -416]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -177, -172, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -177, -174, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -174, -169, -400]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -172, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -177, -166, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -174, -169, -400]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -169, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -177, -166, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -174, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -187, -179, -400]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -172, -156, -400]
# Raw Fixed Output: [4152, 4152]
# Converted Float Output: [0.25341796875, 0.25341796875]
# predicted cmdL=32.18, cmdR=32.18
# [256, 0, 0, -174, -177, -368]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -174, -166, -336]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -164, -159, -368]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -174, -182, -368]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -172, -161, -368]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -172, -174, -400]
# Raw Fixed Output: [3961, 4552]
# Converted Float Output: [0.24176025390625, 0.27783203125]
# predicted cmdL=30.70, cmdR=35.28
# [256, 0, 0, -174, -174, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -187, -189, -384]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -177, -400]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -172, -384]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -179, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -177, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -174, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -174, -174, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -172, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -336]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -174, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -172, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -174, -172, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -177, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -182, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -179, -368]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -177, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -177, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -179, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -192, -192, -352]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -182, -368]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -177, -182, -400]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -182, -400]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -179, -179, -400]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -432]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -177, -169, -432]
# Raw Fixed Output: [3961, 4152]
# Converted Float Output: [0.24176025390625, 0.25341796875]
# predicted cmdL=30.70, cmdR=32.18
# [256, 0, 0, -177, -166, -384]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -179, -169, -368]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -172, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -172, -169, -384]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -172, -169, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -177, -172, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -174, -169, -384]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -174, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -177, -174, -400]
# Raw Fixed Output: [3961, 4349]
# Converted Float Output: [0.24176025390625, 0.26544189453125]
# predicted cmdL=30.70, cmdR=33.71
# [256, 0, 0, -174, -166, -368]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -174, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -169, -368]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -368]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -177, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -174, -172, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -172, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -172, -336]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -179, -172, -304]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -320]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -320]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -174, -174, -304]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -177, -179, -320]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -189, -195, -320]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -177, -184, -336]
# Raw Fixed Output: [3961, 4761]
# Converted Float Output: [0.24176025390625, 0.29058837890625]
# predicted cmdL=30.70, cmdR=36.90
# [256, 0, 0, -182, -179, -368]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -177, -179, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -184, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -182, -182, -368]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -179, -384]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -184, -177, -400]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -172, -416]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -182, -174, -400]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -179, -174, -400]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -179, -166, -400]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -172, -166, -368]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -166, -352]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -169, -336]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -177, -166, -336]
# Raw Fixed Output: [4152, 4349]
# Converted Float Output: [0.25341796875, 0.26544189453125]
# predicted cmdL=32.18, cmdR=33.71
# [256, 0, 0, -172, -169, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -174, -169, -320]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -177, -177, -336]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -179, -320]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -182, -352]
# Raw Fixed Output: [4152, 4761]
# Converted Float Output: [0.25341796875, 0.29058837890625]
# predicted cmdL=32.18, cmdR=36.90
# [256, 0, 0, -179, -177, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -352]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -174, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -182, -179, -336]
# Raw Fixed Output: [4152, 4552]
# Converted Float Output: [0.25341796875, 0.27783203125]
# predicted cmdL=32.18, cmdR=35.28
# [256, 0, 0, -179, -184, -352]
# Raw Fixed Output: [4152, 4975]
# Converted Float Output: [0.25341796875, 0.30364990234375]
# KeyboardInterrupt

# %%
rc.ForwardM1(rc_address, 0)
rc.ForwardM2(rc_address, 0)
# Out:
# True
